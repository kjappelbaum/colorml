# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit

# %%
df = pd.read_csv('../data/color_feat_merged.csv')

# %%
def bin_column(column): 
    binned = []
    for value in column: 
        if value < 85: 
            binned.append(0)
        elif 85 <= value < 170:
            binned.append(1)
        else: 
            binned.append(2)
    return np.array(binned).reshape(-1,1)

# %%
r_binned = bin_column(df['r'].values)
g_binned = bin_column(df['g'].values)
b_binned = bin_column(df['b'].values)

# %%
mlss = MultilabelStratifiedShuffleSplit(n_splits=1, train_size=0.9, test_size=0.1, random_state=34567)
# Out:
# /Users/kevinmaikjablonka/opt/miniconda3/envs/colorml2/lib/python3.7/site-packages/sklearn/utils/validation.py:71: FutureWarning: Pass test_size=0.1, train_size=0.9, random_state=34567 as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)

# %%
for train_idx, test_idx in mlss.split(df, np.hstack([r_binned, g_binned, b_binned])):
    pass

# %%
df_train = df.iloc[train_idx].sample(len(train_idx))

# %%
df_test = df.iloc[test_idx].sample(len(test_idx))

# %%
len(df_test)
# Out:
# 640

# %%
df_train.to_csv('../data/development_set.csv', index=False)

# %%
df_test.to_csv('../data/holdout_set.csv', index=False)

# %%
df_test
# Out:
#       Unnamed: 0  mc_CRY-chi-0-all  mc_CRY-chi-1-all  mc_CRY-chi-2-all  \
# 1812        1812            3.6481         26.281600         19.482000
# 3690        3690            3.5344         29.678933         23.130267
# 1058        1058            1.4400         31.104000         36.864000
# 3156        3156            3.6100         23.864000         42.332000
# 5957        5957            2.9354         13.671100         49.256700
# ...          ...               ...               ...               ...
# 1637        1637            2.7225         21.384000         25.245000
# 2131        2131            2.8561         23.254400         17.238000
# 4780        4780            1.4400         31.956000         16.740000
# 4664        4664            2.8561         26.679467         26.792133
# 5259        5259            1.7161         27.038400         24.759000
#
#       mc_CRY-chi-3-all  mc_CRY-Z-0-all  mc_CRY-Z-1-all  mc_CRY-Z-2-all  \
# 1812         45.763600           784.0          896.00           672.0
# 3690         49.751067           729.0          990.00          1188.0
# 1058         80.304000          3969.0         3780.00          7056.0
# 3156         68.894000           841.0          841.00          2813.0
# 5957         19.670000          3222.5         3966.25          5407.5
# ...                ...             ...             ...             ...
# 1637         51.117000           900.0          900.00          1080.0
# 2131         40.492400          2304.0         1536.00          1152.0
# 4780         42.060000          3969.0         3906.00          5859.0
# 4664         66.800067          2304.0         1760.00          4608.0
# 5259         71.788000           144.0          576.00           744.0
#
#       mc_CRY-Z-3-all  mc_CRY-I-0-all  ...  sum-D_func-alpha-1-all  \
# 1812          1568.0             1.0  ...              -12.000000
# 3690          1521.0             1.0  ...              -67.200000
# 1058          8820.0             1.0  ...               16.200000
# 3156          1972.0             1.0  ...                0.000000
# 5957          5144.0             1.0  ...             -386.120000
# ...              ...             ...  ...                     ...
# 1637          1680.0             1.0  ...              -33.600000
# 2131          2688.0             1.0  ...              -24.000000
# 4780          5166.0             1.0  ...               69.000000
# 4664          4160.0             1.0  ...              -38.493333
# 5259          1536.0             1.0  ...              -11.400000
#
#       sum-D_func-alpha-2-all  sum-D_func-alpha-3-all  color_cleaned   refcode  \
# 1812              -12.000000                  -24.00      colorless    WIHDUN
# 3690              -67.200000                 -150.00            red    AWAWUR
# 1058               -7.800000                   -2.00      colorless    OGIYUZ
# 3156                0.000000                    0.00           blue    MUZRIJ
# 5957                0.000000                 -244.28          brown    SUKKUF
# ...                      ...                     ...            ...       ...
# 1637              -54.000000                  -87.60      colorless    ULEPIM
# 2131              -24.000000                  -48.00      colorless    CUMLUT
# 4780               48.600000                  117.60         yellow    GUKZAO
# 4664              -37.448889                  -54.40         orange    HUFKUQ
# 5259               -4.000000                    3.80         yellow  HOQMIL01
#
#       color_string  delta_t_seconds      r      g      b
# 1812     colorless        23.274056  232.0  234.0  244.0
# 3690           red        13.378720  250.0   11.0    5.0
# 1058     colorless        23.274056  232.0  234.0  244.0
# 3156          blue        19.723303   12.0   26.0  224.0
# 5957         brown        17.611029   91.0   48.0    5.0
# ...            ...              ...    ...    ...    ...
# 1637     colorless        23.274056  232.0  234.0  244.0
# 2131     colorless        23.274056  232.0  234.0  244.0
# 4780        yellow        19.796456  247.5  242.5   16.0
# 4664        orange        22.024030  246.5  132.0    4.0
# 5259        yellow        19.796456  247.5  242.5   16.0
#
# [640 rows x 342 columns]

# %%
from colour.models import RGB_to_HSV

# %%
RGB_to_HSV(df_train[['r', 'g', 'b']])
# Out:
# /Users/kevinmaikjablonka/opt/miniconda3/envs/colorml2/lib/python3.7/site-packages/colour/models/rgb/deprecated.py:123: RuntimeWarning: invalid value encountered in true_divide
#   S = as_float_array(delta / maximum)
# /Users/kevinmaikjablonka/opt/miniconda3/envs/colorml2/lib/python3.7/site-packages/colour/models/rgb/deprecated.py:126: RuntimeWarning: invalid value encountered in true_divide
#   delta_R = (((maximum - R) / 6) + (delta / 2)) / delta
# /Users/kevinmaikjablonka/opt/miniconda3/envs/colorml2/lib/python3.7/site-packages/colour/models/rgb/deprecated.py:127: RuntimeWarning: invalid value encountered in true_divide
#   delta_G = (((maximum - G) / 6) + (delta / 2)) / delta
# /Users/kevinmaikjablonka/opt/miniconda3/envs/colorml2/lib/python3.7/site-packages/colour/models/rgb/deprecated.py:128: RuntimeWarning: invalid value encountered in true_divide
#   delta_B = (((maximum - B) / 6) + (delta / 2)) / delta
# /Users/kevinmaikjablonka/opt/miniconda3/envs/colorml2/lib/python3.7/site-packages/colour/models/rgb/deprecated.py:133: RuntimeWarning: invalid value encountered in less
#   H[np.asarray(H < 0)] += 1
# /Users/kevinmaikjablonka/opt/miniconda3/envs/colorml2/lib/python3.7/site-packages/colour/models/rgb/deprecated.py:134: RuntimeWarning: invalid value encountered in greater
#   H[np.asarray(H > 1)] -= 1
# array([[  3.27345309e-01,   8.74345550e-01,   1.91000000e+02],
#        [  3.27345309e-01,   8.74345550e-01,   1.91000000e+02],
#        [  8.33333333e-02,   9.45054945e-01,   9.10000000e+01],
#        ...,
#        [  6.55660377e-01,   9.46428571e-01,   2.24000000e+02],
#        [  6.55660377e-01,   9.46428571e-01,   2.24000000e+02],
#        [  9.99099099e-01,   9.78835979e-01,   1.89000000e+02]])
